# %% [markdown]
# # PyCity Schools Analysis
#
# * As a whole, schools with higher budgets, did not yield better test results. By contrast, schools with higher spending per student actually (\$645-675) underperformed compared to schools with smaller budgets (<\$585 per student).
#
# * As a whole, smaller and medium sized schools dramatically out-performed large sized schools on passing math performances (89-91% passing vs 67%).
#
# * As a whole, charter schools out-performed the public district schools across all metrics. However, more analysis will be required to glean if the effect is due to school practices or the fact that charter schools tend to serve smaller student populations per school.
# ---

# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd

# File to Load (Remember to Change These)
school_data_to_load = "Resources/schools_complete.csv"
student_data_to_load = "Resources/students_complete.csv"

# Read School and Student Data File and store into Pandas Data Frames
school_data = pd.read_csv(school_data_to_load)
student_data = pd.read_csv(student_data_to_load)

# Combine the data into a single dataset
school_data_complete = pd.merge(student_data, school_data, how="left", on=["school_name", "school_name"])

# %% [markdown]
# ## District Summary
#
# * Calculate the total number of schools
#
# * Calculate the total number of students
#
# * Calculate the total budget
#
# * Calculate the average math score
#
# * Calculate the average reading score
#
# * Calculate the overall passing rate (overall average score), i.e. (avg. math score + avg. reading score)/2
#
# * Calculate the percentage of students with a passing math score (70 or greater)
#
# * Calculate the percentage of students with a passing reading score (70 or greater)
#
# * Create a dataframe to hold the above results
#
# * Optional: give the displayed data cleaner formatting

# %%
numschools = school_data["school_name"].count()

numstudents = student_data["student_name"].count()

totalbudget = school_data["budget"].sum()

mathavg = student_data["math_score"].mean()

readavg = student_data["reading_score"].mean()

# %%
#Percentage of students with a passing math score
passmath = student_data.loc[(student_data["math_score"]) >= 70]
passmathcount = passmath["math_score"].count()
percpassmath = (passmathcount/numstudents) * 100
percpassmath
# Out:
# 74.9808526933878

# %%
#Percentage of students with a passing reading score
passread = student_data.loc[(student_data["reading_score"]) >= 70]
passreadcount = passread["reading_score"].count()
percpassreading = (passreadcount/numstudents) * 100
percpassreading
# Out:
# 85.80546336482001

# %%
#Overall passing rate
overallpass = (percpassmath + percpassreading)/2
overallpass
# Out:
# 80.39315802910392

# %%
#Dataframe to hold results
summary = {
    "Total Schools": numschools,
    "Total Students" : numstudents,
    "Total Budget" : totalbudget,
    "Math Score Average" : mathavg,
    "Reading Score Average" : readavg,
    "Passing Math Percent" : percpassmath,
    "Passing Reading Percent" : percpassreading,
    "Overall Passing Percent" : overallpass  
}

summary_df = pd.DataFrame([summary])
summary_df = summary_df[["Total Schools",
                   "Total Students","Total Budget","Math Score Average", "Reading Score Average",
                   "Passing Math Percent", "Passing Reading Percent", "Overall Passing Percent" ]]

summary_df
# Out:
#    Total Schools  Total Students  Total Budget  Math Score Average  \
# 0             15           39170      24649428           78.985371
#
#    Reading Score Average  Passing Math Percent  Passing Reading Percent  \
# 0               81.87784             74.980853                85.805463
#
#    Overall Passing Percent
# 0                80.393158

# %% [markdown]
# ## School Summary

# %% [markdown]
# * Create an overview table that summarizes key metrics about each school, including:
#   * School Name
#   * School Type
#   * Total Students
#   * Total School Budget
#   * Per Student Budget
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * Overall Passing Rate (Average of the above two)
#
# * Create a dataframe to hold the above results

# %% [markdown]
# ## Top Performing Schools (By Passing Rate)

# %% [markdown]
# * Sort and display the top five schools in overall passing rate

# %%
school_data["per Student Budget"] = school_data["budget"]/school_data["size"]
avgmathreadscore = student_data.groupby(["school_name"])["math_score", "reading_score"].mean().reset_index()
school_data = school_data.merge(avgmathreadscore, how= "outer", on="school_name")

# %%
passreadsum = student_data[student_data["reading_score"]>=70]
passmathsum = student_data[student_data["math_score"]>=70]
passread_count = passreadsum.groupby(["school_name"])["reading_score"].count().reset_index()

# %%
passcounter = passmathsum.merge(passreadsum, how = "inner", on="school_name", suffixes = )
passcounter
# Out:
#           Student ID_x   student_name_x gender_x grade_x         school_name  \
# 78013520               95            75         39156  Stephanie Contreras
# 78013521               95            75         39157     Kristen Gonzalez
# 78013522               95            75         39158        Kari Holloway
# 78013523               95            75         39159     Kimberly Cabrera
# 78013524               95            75         39160         Katie Weaver
# 78013525               95            75         39161          April Reyes
# 78013526               95            75         39162          Derek Weeks
# 78013527               95            75         39163           John Reese
# 78013528               95            75         39164       Joseph Anthony
# 78013529               95            75         39165         Donna Howard
# 78013530               95            75         39166            Dawn Bell
# 78013531               95            75         39167       Rebecca Tanner
# 78013532               95            75         39168         Desiree Kidd
# 78013533               95            75         39169      Carolyn Jackson
#
#          gender_y grade_y  reading_score_y  math_score_y
# 0               M    12th               94            61
# 1               M    12th               90            60
# 2               F     9th               97            84
# 3               M     9th               94            94
# 4               F    11th               82            80
# 5               F    12th               96            69
# 6               M    10th               95            87
# 7               M    10th               96            84
# 8               M    10th               90            70
# 9               M    10th               78            77
# 10              M     9th               71            79
# 11              F    10th               85            67
# 12              M    11th               94            88
# 13              M     9th               88            55
# 14              F     9th               74            75
# 15              F     9th               89            80
# 16              F    10th               91            89
# 17              F    10th               90            77
# 18              F    11th               99            84
# 19              M     9th               81            68
# 20              F    11th               85            73
# 21              M     9th               92            70
# 22              F    10th               80            58
# 23              F    11th               73            55
# 24              F    12th               90            88
# 25              M     9th               94            99
# 26              M    10th               97            65
# 27              F    11th               93            90
# 28              F    12th               95            68
# 29              M    10th               99            61
# ...           ...     ...              ...           ...
# 78013504        F     9th               83            81
# 78013505        F     9th               76            99
# 78013506        M    10th               86            93
# 78013507        F    10th               96            83
# 78013508        M    11th               71            93
# 78013509        M    12th               77            87
# 78013510        F    10th               94            74
# 78013511        M    10th               88            81
# 78013512        M    10th               89            89
# 78013513        F    11th               82            93
# 78013514        F    11th               80            75
# 78013515        F    10th               84            73
# 78013516        F     9th               98            84
# 78013517        M     9th               80            75
# 78013518        M    12th               91            71
# 78013519        M    10th               92            98
# 78013520        F    11th               79            95
# 78013521        F     9th               79            94
# 78013522        F    10th               87            90
# 78013523        F    11th               85            72
# 78013524        F    11th               89            86
# 78013525        F    10th               70            84
# 78013526        M    12th               94            77
# 78013527        M    11th               90            75
# 78013528        M     9th               97            76
# 78013529        F    12th               99            90
# 78013530        F    10th               95            70
# 78013531        F     9th               73            84
# 78013532        F    10th               99            90
# 78013533        F    11th               95            75
#
# [78013534 rows x 13 columns]

# %% [markdown]
# ## Bottom Performing Schools (By Passing Rate)

# %% [markdown]
# * Sort and display the five worst-performing schools

# %% [markdown]
# ## Math Scores by Grade

# %% [markdown]
# * Create a table that lists the average Reading Score for students of each grade level (9th, 10th, 11th, 12th) at each school.
#
#   * Create a pandas series for each grade. Hint: use a conditional statement.
#
#   * Group each series by school
#
#   * Combine the series into a dataframe
#
#   * Optional: give the displayed data cleaner formatting

# %% [markdown]
# ## Reading Score by Grade

# %% [markdown]
# * Perform the same operations as above for reading scores

# %% [markdown]
# ## Scores by School Spending

# %% [markdown]
# * Create a table that breaks down school performances based on average Spending Ranges (Per Student). Use 4 reasonable bins to group school spending. Include in the table each of the following:
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * Overall Passing Rate (Average of the above two)

# %%
# Sample bins. Feel free to create your own bins.
spending_bins = [0, 585, 615, 645, 675]
group_names = ["<$585", "$585-615", "$615-645", "$645-675"]

# %% [markdown]
# ## Scores by School Size

# %% [markdown]
# * Perform the same operations as above, based on school size.

# %%
# Sample bins. Feel free to create your own bins.
size_bins = [0, 1000, 2000, 5000]
group_names = ["Small (<1000)", "Medium (1000-2000)", "Large (2000-5000)"]

# %% [markdown]
# ## Scores by School Type

# %% [markdown]
# * Perform the same operations as above, based on school type.
